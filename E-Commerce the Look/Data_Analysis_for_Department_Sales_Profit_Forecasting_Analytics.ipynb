# %% [markdown]
# # 2.Data Understanding

# %% [markdown]
# [![Open In Collab](https://colab.research.google.com/assets/colab-badge.svg)](https://drive.google.com/file/d/1i_kE6pyKn4k77aADwQDrNO6vOSlBYJzb/view?usp=sharing)

# %% [markdown]
# ## 2.1 Define Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# Beberapa library yang biasa digunakan untuk mempermudah dalam melakukan explorasi data dengan python adalah pandas, matplotlib, seaborn dan numpy. Pandas dan numpy mempermudah dalam pemrosesan data numeric dan analisis data sedangkan matplotlib dan seaborn berfungsi dalam menciptakan visualisasi.

# %% [markdown]
# ##2.2 Connecting GC with my own drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##2.3 Read Dataset
# Dataset yang digunakan merupakan dataset yang sudah dimodivakasi dari 3 tabel (orders_item, users, dan orders) menggunakan SQL

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data_for_pyhton_all_status.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124512 entries, 0 to 124511
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           124512 non-null  int64
#  1   user_id            124512 non-null  int64
#  2   product_id         124512 non-null  int64
#  3   inventory_item_id  124512 non-null  int64
#  4   status             124512 non-null  object
#  5   created_at         124512 non-null  object
#  6   shipped_at         80844 non-null   object
#  7   delivered_at       43138 non-null   object
#  8   returned_at        12123 non-null   object
#  9   sale_price         124512 non-null  float64
#  10  num_of_item        124512 non-null  int64
#  11  cost               124512 non-null  float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ## 2.4 Explonatory Data Analysis

# %% [markdown]
# ### 2.4.1 Eksplorasi Data

# %% [markdown]
# #### 1) Head and Tail Data

# %%
data.head()
# Out:
#    order_id  user_id  product_id  inventory_item_id      status           created_at           shipped_at         delivered_at returned_at  sale_price  num_of_item       cost
# 0         1        1       26458                  9    Complete  2019-07-20 14:45:53  2019-07-18 07:58:00  2019-07-22 10:36:00         NaN       11.99            1   5.515400
# 1         1        1       16783                  2    Complete  2019-07-20 14:29:35  2019-07-18 07:58:00  2019-07-22 10:36:00         NaN       55.00            4  28.325000
# 2         1        1       21357                  5    Complete  2019-07-21 16:59:28  2019-07-18 07:58:00  2019-07-22 10:36:00         NaN       68.95            1  35.095547
# 3         1        1       27726                 13    Complete  2019-07-19 15:45:02  2019-07-18 07:58:00  2019-07-22 10:36:00         NaN       49.99            2  28.294340
# ...

# %%
data.tail()
# Out:
#         order_id  user_id  product_id  inventory_item_id     status           created_at           shipped_at         delivered_at returned_at  sale_price  num_of_item      cost
# 124507     86098    69088       21994             336064   Complete  2022-05-13 00:38:50  2022-05-13 22:50:00  2022-05-18 16:18:00         NaN       79.00            1  34.68100
# 124508     86099    69090       16335             336066    Shipped  2022-05-10 03:22:51  2022-05-12 13:26:00                  NaN         NaN       29.99            1  16.73442
# 124509     86100    69091       20143             336068  Cancelled  2021-04-24 06:22:00                  NaN                  NaN         NaN       84.66            1  30.73158
# 124510     86101    69091       16591             336070  Cancelled  2020-04-13 05:55:22                  NaN                  NaN         NaN       28.95            1  15.89355
# ...

# %% [markdown]
# #### 2) Total Number of Rows and Columns

# %%
data.shape
# Out:
# (124512, 12)

# %%
data.columns
# Out:
# Index(['order_id', 'user_id', 'product_id', 'inventory_item_id', 'status', 'created_at', 'shipped_at', 'delivered_at', 'returned_at', 'sale_price', 'num_of_item', 'cost'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=124512, step=1)

# %% [markdown]
# Dataset ditampilkan terdiri dari 366587 baris dan 12 kolom, dimana nama variabel untuk ke 14 kolom tersebut dapat diketahui dengan menggunakan fungsi df.columns sedangkan index pada data berada pada range 0 sampai 3665587 dengan kenaikan atau step = 1. Berdasarkan data diatas colomn ‘created_at’,'shipped_at' dan 'return_at' merupakan independent variabel sedangkan sisanya adalah dependen variabel.

# %%
data.created_at.unique()
# Out:
# array(['2019-07-20 14:45:53', '2019-07-20 14:29:35',
#        '2019-07-21 16:59:28', ..., '2021-04-24 06:22:00',
#        '2020-04-13 05:55:22', '2020-04-14 03:40:11'], dtype=object)

# %% [markdown]
# #### 3) Missing Value

# %%
data.isna()
# Out:
#         order_id  user_id  product_id  inventory_item_id  status  created_at  shipped_at  delivered_at  returned_at  sale_price  num_of_item   cost
# 0          False    False       False              False   False       False       False         False         True       False        False  False
# 1          False    False       False              False   False       False       False         False         True       False        False  False
# 2          False    False       False              False   False       False       False         False         True       False        False  False
# 3          False    False       False              False   False       False       False         False         True       False        False  False
# 4          False    False       False              False   False       False        True          True         True       False        False  False
# ...

# %%
data.isnull().any()
# Out:
# order_id             False
# user_id              False
# product_id           False
# inventory_item_id    False
# status               False
# created_at           False
# shipped_at            True
# delivered_at          True
# returned_at           True
# sale_price           False
# num_of_item          False
# cost                 False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# product_id                0
# inventory_item_id         0
# status                    0
# created_at                0
# shipped_at            43668
# delivered_at          81374
# returned_at          112389
# sale_price                0
# num_of_item               0
# cost                      0
# dtype: int64

# %% [markdown]
# #### 4) Handling Missing Value for times series
# ref : https://www.projectpro.io/recipes/deal-with-missing-values-in-timeseries-in-python

# %% [markdown]
# ###### a. Forward-fill Missing Values
# Using value of next row to fill the missing value

# %%
data2 = data.ffill()
print(data2)
# Out:
#         order_id  user_id  product_id  inventory_item_id      status           created_at           shipped_at         delivered_at          returned_at  sale_price  num_of_item       cost
# 0              1        1       26458                  9    Complete  2019-07-20 14:45:53  2019-07-18 07:58:00  2019-07-22 10:36:00                  NaN       11.99            1   5.515400
# 1              1        1       16783                  2    Complete  2019-07-20 14:29:35  2019-07-18 07:58:00  2019-07-22 10:36:00                  NaN       55.00            4  28.325000
# 2              1        1       21357                  5    Complete  2019-07-21 16:59:28  2019-07-18 07:58:00  2019-07-22 10:36:00                  NaN       68.95            1  35.095547
# 3              1        1       27726                 13    Complete  2019-07-19 15:45:02  2019-07-18 07:58:00  2019-07-22 10:36:00                  NaN       49.99            2  28.294340
# ...

# %%
data2.isnull().sum()
# Out:
# order_id              0
# user_id               0
# product_id            0
# inventory_item_id     0
# status                0
# created_at            0
# shipped_at            0
# delivered_at          0
# returned_at          16
# sale_price            0
# num_of_item           0
# cost                  0
# dtype: int64

# %% [markdown]
# ###### b. Backfill Missing Values
# Using value of previous row to fill the missing value

# %%
data3 = data2.bfill();
print(data3)
# Out:
#         order_id  user_id  product_id  inventory_item_id      status           created_at           shipped_at         delivered_at          returned_at  sale_price  num_of_item       cost
# 0              1        1       26458                  9    Complete  2019-07-20 14:45:53  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       11.99            1   5.515400
# 1              1        1       16783                  2    Complete  2019-07-20 14:29:35  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       55.00            4  28.325000
# 2              1        1       21357                  5    Complete  2019-07-21 16:59:28  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       68.95            1  35.095547
# 3              1        1       27726                 13    Complete  2019-07-19 15:45:02  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       49.99            2  28.294340
# ...

# %%
data3.isnull().sum()
# Out:
# order_id             0
# user_id              0
# product_id           0
# inventory_item_id    0
# status               0
# created_at           0
# shipped_at           0
# delivered_at         0
# returned_at          0
# sale_price           0
# num_of_item          0
# cost                 0
# dtype: int64

# %%
data3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 5) Data Info

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124512 entries, 0 to 124511
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           124512 non-null  int64
#  1   user_id            124512 non-null  int64
#  2   product_id         124512 non-null  int64
#  3   inventory_item_id  124512 non-null  int64
#  4   status             124512 non-null  object
#  5   created_at         124512 non-null  object
#  6   shipped_at         124512 non-null  object
#  7   delivered_at       124512 non-null  object
#  8   returned_at        124512 non-null  object
#  9   sale_price         124512 non-null  float64
#  10  num_of_item        124512 non-null  int64
#  11  cost               124512 non-null  float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ###2.4.2 Analisa Statistika Deskriptif
# saya akan melakukan eksplorasi data dengan menggunakan statistika deskriptif. Statistika deskriptif adalah metode-metode yang berkaitan dengan pengumpulan dan penyajian suatu gugus data sehingga memberikan informasi yang berguna, ada 3 cara yang umum digunakan untuk mendeskripsikan data sebagai berikut

# %% [markdown]
# #### 1) Measures of Central Tendency
# mendeskripsikan posisi titik tengah dari distribusi frekuensi suatu kelompok.

# %% [markdown]
# ##### a. Mean
# Mean adalah jumlah dari seluruh data continous (numerical) dibagi dengan jumlah data yang ada. Mean adalah measure of central yang paling sering digunakan untuk data numerical

# %%
data4=data3[['order_id', 'user_id','product_id','inventory_item_id','sale_price','num_of_item','cost']]
data4.mean()
# Out:
# order_id              43086.956165
# user_id               34689.605612
# product_id            15284.414482
# inventory_item_id    168119.689765
# sale_price               59.880617
# num_of_item               1.449724
# cost                     28.784102
# dtype: float64

# %% [markdown]
# ##### b. Median
# Median adalah nilai tengah dari suatu data numerical yang diurutkan. jika jumlah data ganjil, maka nilai median tepat berada tengah dari data, sedangkan apabila genap maka nilai median berada diantara kedua nilai yang berada ditengah. Median lebih sering digunakan jika mean tidak mampu menjelaskan data kita dengan baik

# %%
data4.median()
# Out:
# order_id              43030.50
# user_id               34748.50
# product_id            16022.00
# inventory_item_id    168174.50
# sale_price               39.99
# num_of_item               1.00
# cost                     19.95
# dtype: float64

# %% [markdown]
# ##### c. Mode
# Mode adalah suatu data categorical atau data continous yang dapat dihitung dimana frekuensi dari data tersebut paling besar atau data yang paling sering muncul.

# %%
data4.mode()
# Out:
#         order_id  user_id  product_id  inventory_item_id  sale_price  num_of_item  cost
# 0            1.0  61518.0     16804.0                  2        25.0          1.0  11.4
# 1            8.0      NaN         NaN                  5         NaN          NaN   NaN
# 2           38.0      NaN         NaN                  9         NaN          NaN   NaN
# 3           84.0      NaN         NaN                 13         NaN          NaN   NaN
# 4           89.0      NaN         NaN                 15         NaN          NaN   NaN
# ...          ...      ...         ...                ...         ...          ...   ...
# 124507       NaN      NaN         NaN             336064         NaN          NaN   NaN
# 124508       NaN      NaN         NaN             336066         NaN          NaN   NaN
# 124509       NaN      NaN         NaN             336068         NaN          NaN   NaN
# 124510       NaN      NaN         NaN             336070         NaN          NaN   NaN
# ...

# %%
data4.describe()
# Out:
#             order_id        user_id     product_id  inventory_item_id     sale_price    num_of_item           cost
# count  124512.000000  124512.000000  124512.000000      124512.000000  124512.000000  124512.000000  124512.000000
# mean    43086.956165   34689.605612   15284.414482      168119.689765      59.880617       1.449724      28.784102
# std     24884.387578   19926.942593    8412.585098       97056.778429      66.230742       0.802567      30.842362
# min         1.000000       1.000000       1.000000           2.000000       0.020000       1.000000       0.008300
# 25%     21567.750000   17493.500000    8016.000000       83985.500000      24.880000       1.000000      11.398390
# 50%     43030.500000   34748.500000   16022.000000      168174.500000      39.990000       1.000000      19.950000
# 75%     64690.250000   51971.250000   22555.000000      252246.750000      69.980000       2.000000      34.725000
# ...

# %% [markdown]
# #### 2) Measures of Spread
# Digunanakan untuk mendeskripsikan seberapa menyebar data yang ada.

# %% [markdown]
# ##### a. Range
# perbedaan antara nilai terbesar dengan nilai terkecil pada data. range menjelaskan seberapa jauh data kita tersebar.

# %%
data4=data3[['order_id', 'user_id','product_id','inventory_item_id','sale_price','cost','num_of_item']]
Range=data4.max()-data4.min()
Range
# Out:
# order_id              86100.0000
# user_id               69090.0000
# product_id            29119.0000
# inventory_item_id    336071.0000
# sale_price              998.9800
# cost                    557.1427
# num_of_item               3.0000
# dtype: float64

# %% [markdown]
# ##### b. Variance
# mengukur seberapa menyebar data yang ada dari mean-nya. Jika nilai variance dari data kita kecil, maka data tersebar dekat nilai mean-nya sedangkan jika nilai variance besar maka menunjukan data tersebar jauh dari mean-nya

# %%
data4.var()
# Out:
# order_id             6.192327e+08
# user_id              3.970830e+08
# product_id           7.077159e+07
# inventory_item_id    9.420018e+09
# sale_price           4.386511e+03
# cost                 9.512513e+02
# num_of_item          6.441139e-01
# dtype: float64

# %% [markdown]
# ##### c. Standar Deviation
# menunjukan seberapa berbeda nilai pada data terhadap rata-ratanya, sama seperti variance, semakin besar nilai standart deviasi semakin jauh nilai dari mean-nya

# %%
data4.std()
# Out:
# order_id             24884.387578
# user_id              19926.942593
# product_id            8412.585098
# inventory_item_id    97056.778429
# sale_price              66.230742
# cost                    30.842362
# num_of_item              0.802567
# dtype: float64

# %% [markdown]
# Untuk mempermudah menganalisis persebaran data, kita dapat menggunakan visualisasi boxplot sebagai berikut

# %%
sns.boxplot(x="sale_price", data=data3);

# %%
# q11,q31=np.percentile(data4['sale_price'],[25,75])
# s1=q31-q11
# ba1=q31+(1.5*s1)
# bw1=q11-(1.5*s1)
# print(q11)
# print(q31)
# print(s1)
# print(ba1)
# print(bw1)

# %%
Q1=data3['sale_price'].quantile(0.25)
Q3=data3['sale_price'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)

Lower_Whisker= Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 24.88
# 69.98
# 45.10000000000001
# -42.77000000000001 137.63

# %%
data5 = data3[data3['sale_price']< Upper_Whisker]

# %%
data5.shape
# Out:
# (113504, 12)

# %%
sns.boxplot(x="num_of_item", data=data5);

# %%
Q1=data5['num_of_item'].quantile(0.25)
Q3=data5['num_of_item'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)

Lower_Whisker= Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 1.0
# 2.0
# 1.0
# -0.5 3.5

# %%
data6 = data5[data5['num_of_item']< Upper_Whisker]

# %%
data6.shape
# Out:
# (107935, 12)

# %%
sns.boxplot(x="cost", data=data6);

# %%
Q1=data6['cost'].quantile(0.25)
Q3=data6['cost'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)

Lower_Whisker= Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 10.8
# 29.592
# 18.791999999999998
# -17.387999999999995 57.779999999999994

# %%
data7 = data6[data6['cost']< Upper_Whisker]

# %%
data7.shape
# Out:
# (105128, 12)

# %%
# data5=data4[(data4['sale_price']<bw1)| (data4['sale_price']>ba1)]
# data5

# %%
# data4=data3.drop([20,21])
# data4

# %%
# data5= pd.DataFrame(data = np.random.random(size=(8,7)), columns = ['order_id'	,'user_id','product_id','inventory_item_id'	,'sale_price','num_of_item','cost'])
# sns.boxplot(x="variable", y="value", data=pd.melt(data5))
# plt.figure(figsize=(155,1))

# %%
# Q1=df['cost'].quantile(0.25)
# Q3=df['cost'].quantile(0.75)
# IQR=Q3-Q1
# print(Q1)
# print(Q3)
# print(IQR)

# Lower_Whisker= Q1-1.5*IQR
# Upper_Whisker = Q3+1.5*IQR
# print(Lower_Whisker, Upper_Whisker)

# %%
# df = df[df['cost']< Upper_Whisker]

# %%
# df = pd.DataFrame(data = np.random.random(size=(8,3)), columns = ['sale_price','cost','num_of_item'])
# #df = pd.DataFrame(data = np.random.random(size=(8,1)), columns = ['num_of_item'])

# sns.boxplot(x="variable", y="value", data=pd.melt(df))
# plt.figure(figsize=(155,1))

# %% [markdown]
# Selain menggunakan boxplot untuk melihat persebaran data, Digunakan  histogram untuk melihat persebaran data berdasarkan frequensi, sebagai berikut:

# %%
data7.hist(figsize=(16, 20), bins=50, xlabelsize=4, ylabelsize=4)
plt.show()

# %% [markdown]
# Sebagai informasi tambahan selain menggunakan visualisasi data untuk merangkum persebaran data, anda juga dapat menggunakan fungsi describes() yang akan memberikan informasi mengenai measures of tendency dan measures of spread data dalam sebuah tabel

# %%
data7.describe()
# Out:
#             order_id        user_id     product_id  inventory_item_id     sale_price    num_of_item           cost
# count  105128.000000  105128.000000  105128.000000      105128.000000  105128.000000  105128.000000  105128.000000
# mean    43074.711028   34679.923208   15341.403261      168071.822959      42.499863       1.316975      20.613450
# std     24868.242527   19913.994676    8458.086085       96993.741545      26.880142       0.567715      12.786367
# min         1.000000       1.000000       1.000000           5.000000       0.020000       1.000000       0.008300
# 25%     21584.750000   17504.000000    8153.000000       84038.500000      22.000000       1.000000      10.625000
# 50%     43013.500000   34736.000000   15877.000000      168100.000000      36.000000       1.000000      17.676000
# 75%     64643.250000   51929.250000   22795.000000      252061.500000      58.000000       2.000000      28.438000
# ...

# %% [markdown]
# #### 3) Shape of Distribution

# %% [markdown]
# ##### a. Skewness

# %%
skew = data7.skew().to_frame()
skew
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#                           0
# order_id           0.000335
# user_id           -0.007778
# product_id        -0.120262
# inventory_item_id  0.001174
# sale_price         0.971781
# num_of_item        1.617932
# cost               0.816528

# %%
sns.distplot(data7['sale_price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data7.shape
# Out:
# (105128, 12)

# %%
number_of_columns=12

# %%
number_of_rows=105128

# %%
# plt.figure(figsize=(2*number_of_columns,10*number_of_rows))
# for i in range(0,len(l)):
#     plt.subplot(number_of_rows + 1,number_of_columns,i+1)
#     sns.distplot(data7[l[i]],kde=True)

# %% [markdown]
# ##### b. Kurtosis

# %%
kurtosis = data7.kurtosis().to_frame()
kurtosis
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#                           0
# order_id          -1.200835
# user_id           -1.198569
# product_id        -1.175164
# inventory_item_id -1.200213
# sale_price         0.443568
# num_of_item        1.599991
# cost              -0.060235

# %%
skew['1'] = kurtosis

# %%
skew.columns = ['skewness','kurtosis']

# %%
skew
# Out:
#                    skewness  kurtosis
# order_id           0.000335 -1.200835
# user_id           -0.007778 -1.198569
# product_id        -0.120262 -1.175164
# inventory_item_id  0.001174 -1.200213
# sale_price         0.971781  0.443568
# num_of_item        1.617932  1.599991
# cost               0.816528 -0.060235

# %%
data4 = data4.reindex(columns=['order_id','user_id','product_id','inventory_item_id','sale_price','num_of_item','cost'])
columns = ['order_id','user_id','product_id','inventory_item_id','sale_price','num_of_item','cost']
data4 = data4.reindex(columns=columns)
data4[columns] = data4[columns].astype(int)

# %%
sns.set()
cols = ['order_id','user_id','product_id','inventory_item_id','sale_price','num_of_item','cost']
sns.pairplot(data7[cols], height = 2.5)
plt.show()

# %% [markdown]
# ##### c. Correlation

# %%
data7.corr()
# Out:
#                    order_id   user_id  product_id  inventory_item_id  sale_price  num_of_item      cost
# order_id           1.000000  0.999994   -0.008712           0.999998    0.003935     0.006470  0.004047
# user_id            0.999994  1.000000   -0.008718           0.999993    0.003942     0.006470  0.004057
# product_id        -0.008712 -0.008718    1.000000          -0.008719   -0.001224     0.007099 -0.003948
# inventory_item_id  0.999998  0.999993   -0.008719           1.000000    0.003938     0.006471  0.004050
# sale_price         0.003935  0.003942   -0.001224           0.003938    1.000000    -0.002380  0.964298
# num_of_item        0.006470  0.006470    0.007099           0.006471   -0.002380     1.000000 -0.004064
# cost               0.004047  0.004057   -0.003948           0.004050    0.964298    -0.004064  1.000000

# %% [markdown]
# Untuk mempermudah dalam analisis, kita juga dapat menggunakan visualisasi heatmap yang disediakan oleh seaborn untuk menampilkan data korelasi antar variabel.

# %%
#Quality correlation matrix
k = 24 #number of variables for heatmap
cols = data.corr().nlargest(k, 'order_id')['order_id'].index
cm = data[cols].corr()
plt.figure(figsize=(15,10))
sns.heatmap(cm, annot=True, cmap = 'viridis')
plt.show()

# %%
cols
# Out:
# Index(['order_id', 'inventory_item_id', 'user_id', 'num_of_item', 'cost', 'sale_price', 'product_id'], dtype='object')

# %% [markdown]
# Dari heatmap diatas, semakin cerah warna pada box menunjukan semakin tinggi nilai korelasi antara 2 variabel.

# %%
plt.figure(figsize=(7, 7))

sns.heatmap(cm[(cm >= 0.7) | (cm <= -0.5)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, square=True);

# %% [markdown]
# variabel yang memiliki korelasi paling tinggi adalah variabel order_id dengan age, hal ini berarti semakin bertambahnya order_id maka nilai umur juga akan bertambah. Untuk membuktikan hal tersebut kita dapat menggunakan scatter plot untuk melihat hubungan antar variabel year dan popularity

# %%
plt.figure(figsize = (4,4))
sns.scatterplot(y = data7['sale_price'], x = data3['cost'])
plt.show()

# %% [markdown]
# Berbeda dengan kedua variabel diatas, variabel inventory_item_id dengan user_id menunjukan nilai korelasi yang sangat kecil -0.71, hal ini menunjukan nilai kedua variabel tersebut berbanding terbalik seperti yang ditunjukan diagram scatter dibawah ini

# %% [markdown]
# korelasi antara seluruh variabel dengan 1 variabel, sebagai contoh, saya ingin melihat bagaimana tren keseluruhan variabel dari tahun ketahun, untuk menjawab pertanyaan tersebut anda dapat menggunakan scatter plot seperti gambar dibawah

# %%
data7.sale_price
# Out:
# 0         11.99
# 2         68.95
# 3         49.99
# 4         42.00
# 5         47.99
#           ...
# 124507    79.00
# 124508    29.99
# 124509    84.66
# 124510    28.95
# 124511    27.77
# Name: sale_price, Length: 105128, dtype: float64

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00",
             "#00BA38", "#00C19F", "#00B9E3",
             "#619CFF", "#DB72FB"]
data7.plot(style='-', figsize=(15,5), color=color_pal[0], y='sale_price', x='created_at', title="Profit")
plt.show()

# %% [markdown]
# # 3.Prepocessing Dataset

# %% [markdown]
# ##3.1 Transformasi Dataset

# %%
data8 = data7[~data['status'].isin (['Cancelled','Shipped','Processing'])]
data8
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         order_id  user_id  product_id  inventory_item_id    status           created_at           shipped_at         delivered_at          returned_at  sale_price  num_of_item       cost
# 0              1        1       26458                  9  Complete  2019-07-20 14:45:53  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       11.99            1   5.515400
# 2              1        1       21357                  5  Complete  2019-07-21 16:59:28  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       68.95            1  35.095547
# 3              1        1       27726                 13  Complete  2019-07-19 15:45:02  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       49.99            2  28.294340
# ...

# %%
data8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36326 entries, 0 to 124507
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           36326 non-null  int64
#  1   user_id            36326 non-null  int64
#  2   product_id         36326 non-null  int64
#  3   inventory_item_id  36326 non-null  int64
#  4   status             36326 non-null  object
#  5   created_at         36326 non-null  object
#  6   shipped_at         36326 non-null  object
#  7   delivered_at       36326 non-null  object
#  8   returned_at        36326 non-null  object
#  9   sale_price         36326 non-null  float64
#  10  num_of_item        36326 non-null  int64
#  11  cost               36326 non-null  float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 3.6+ MB

# %%
data8['Profit']=data8['num_of_item']*data8['sale_price'] - data8['cost']
print(data8)
# Out:
#         order_id  user_id  product_id  inventory_item_id    status           created_at           shipped_at         delivered_at          returned_at  sale_price  num_of_item       cost      Profit
# 0              1        1       26458                  9  Complete  2019-07-20 14:45:53  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       11.99            1   5.515400    6.474600
# 2              1        1       21357                  5  Complete  2019-07-21 16:59:28  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       68.95            1  35.095547   33.854453
# 3              1        1       27726                 13  Complete  2019-07-19 15:45:02  2019-07-18 07:58:00  2019-07-22 10:36:00  2021-12-30 22:17:00       49.99            2  28.294340   71.685660
# ...

# %%
data8['delivered_at']=pd.to_datetime(data8['delivered_at'], infer_datetime_format=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# data8['Month']= data8['created_at'].dt.strftime('%Y-%U')
# data8['Month']= data8['delivered_at'].dt.strftime('%Y-%U')
data8['Month'] =  pd.to_datetime(data8['delivered_at'].dt.strftime('%Y-%m-%d'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# data8=data8.groupby('Month').size().sort_values(ascending=True)
data8 = data8.sort_values(by="Month")

# %%
data8
# Out:
#         order_id  user_id  product_id  inventory_item_id    status                  created_at                  shipped_at               delivered_at                 returned_at  sale_price  num_of_item      cost     Profit      Month
# 51994      35953    29050       17357             140389  Complete         2019-01-05 05:39:08         2019-01-06 05:58:00 2019-01-06 09:44:00.000000  2022-06-04 06:53:34.020333       79.95            2  44.77200  115.12800 2019-01-06
# 51993      35953    29050       25284             140393  Complete         2019-01-08 04:16:03         2019-01-06 05:58:00 2019-01-06 09:44:00.000000  2022-06-04 06:53:34.020333       18.00            1  10.99800    7.00200 2019-01-06
# 59448      41109    33204       19579             160533  Complete         2019-01-13 01:12:59         2019-01-14 14:12:00 2019-01-15 18:21:00.000000         2021-11-02 12:30:00       74.50            1  36.20700   38.29300 2019-01-15
# ...

# %%
data8.isnull().sum()
# Out:
# order_id             0
# user_id              0
# product_id           0
# inventory_item_id    0
# status               0
# created_at           0
# shipped_at           0
# delivered_at         0
# returned_at          0
# sale_price           0
# num_of_item          0
# cost                 0
# Profit               0
# Month                0
# dtype: int64

# %%
data8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36326 entries, 51994 to 18465
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           36326 non-null  int64
#  1   user_id            36326 non-null  int64
#  2   product_id         36326 non-null  int64
#  3   inventory_item_id  36326 non-null  int64
#  4   status             36326 non-null  object
#  5   created_at         36326 non-null  object
#  6   shipped_at         36326 non-null  object
#  7   delivered_at       36326 non-null  datetime64[ns]
#  8   returned_at        36326 non-null  object
#  9   sale_price         36326 non-null  float64
#  10  num_of_item        36326 non-null  int64
#  11  cost               36326 non-null  float64
#  12  Profit             36326 non-null  float64
#  13  Month              36326 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(5), object(4)
# memory usage: 4.2+ MB

# %%
# Tahun=data8['created_at'].dt.year
# Bulan=data8['created_at'].dt.month
# data8['Month']=TahunBulan
# data8

# data8['month'] = data8['created_at'].dt.to_period('M')
# data8
# data9['month'] =  pd.to_datetime(data9['month'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
data9= data8.drop(columns=["order_id","user_id","product_id","inventory_item_id","status","shipped_at","delivered_at","returned_at","sale_price","cost",'num_of_item','created_at'])
print(data9)
# Out:
#            Profit      Month
# 51994   115.12800 2019-01-06
# 51993     7.00200 2019-01-06
# 59448    38.29300 2019-01-15
# 84907    32.54400 2019-01-17
# 112419    9.63600 2019-01-18
# ...           ...        ...
# 72100    26.91000 2022-06-09
# 81477    14.54400 2022-06-09
# 72102    46.62000 2022-06-09
# 23409    98.68355 2022-06-09
# 18465    49.40400 2022-06-09
#
# [36326 rows x 2 columns]

# %%
data9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36326 entries, 51994 to 18465
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Profit  36326 non-null  float64
#  1   Month   36326 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 851.4 KB

# %%
# # data9['Month']=pd.to_datetime(data8['Month'], infer_datetime_format=True)
# # data8['created_at']=pd.to_datetime(data8['created_at'], infer_datetime_format=True)
# data10 = data9.set_index(["Month"])

# %%
data10=data9.groupby(pd.Grouper(key='Month', freq='7D')).count()

# %%
data10
# Out:
#             Profit
# Month
# 2019-01-06       2
# 2019-01-13       3
# 2019-01-20       6
# 2019-01-27       5
# 2019-02-03       1
# 2019-02-10       4
# 2019-02-17       6
# 2019-02-24      12
# 2019-03-03      11
# 2019-03-10      12
# 2019-03-17      12
# 2019-03-24       9
# 2019-03-31       7
# 2019-04-07      13
# 2019-04-14      27
# 2019-04-21      27
# 2019-04-28      18
# 2019-05-05      36
# 2019-05-12      28
# 2019-05-19      33
# 2019-05-26      25
# 2019-06-02      37
# 2019-06-09      16
# 2019-06-16      19
# 2019-06-23      29
# 2019-06-30      22
# 2019-07-07      40
# 2019-07-14      36
# 2019-07-21      50
# 2019-07-28      35
# 2019-08-04      47
# 2019-08-11      33
# 2019-08-18      66
# 2019-08-25      49
# 2019-09-01      42
# 2019-09-08      42
# 2019-09-15      57
# 2019-09-22      61
# 2019-09-29      49
# 2019-10-06      48
# 2019-10-13      50
# 2019-10-20      54
# 2019-10-27      67
# 2019-11-03      50
# 2019-11-10      55
# 2019-11-17      63
# ...

# %%
# data9['Year-Week']= data9['Month'].dt.strftime('%Y-%U')

# %%
data10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 179 entries, 2019-01-06 to 2022-06-05
# Freq: 7D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Profit  179 non-null    int64
# dtypes: int64(1)
# memory usage: 2.8 KB

# %%
data10["Profit"] = data10["Profit"].apply(np.int64)

# %%
data10
# Out:
#             Profit
# Month
# 2019-01-06       2
# 2019-01-13       3
# 2019-01-20       6
# 2019-01-27       5
# 2019-02-03       1
# 2019-02-10       4
# 2019-02-17       6
# 2019-02-24      12
# 2019-03-03      11
# 2019-03-10      12
# 2019-03-17      12
# 2019-03-24       9
# 2019-03-31       7
# 2019-04-07      13
# 2019-04-14      27
# 2019-04-21      27
# 2019-04-28      18
# 2019-05-05      36
# 2019-05-12      28
# 2019-05-19      33
# 2019-05-26      25
# 2019-06-02      37
# 2019-06-09      16
# 2019-06-16      19
# 2019-06-23      29
# 2019-06-30      22
# 2019-07-07      40
# 2019-07-14      36
# 2019-07-21      50
# 2019-07-28      35
# 2019-08-04      47
# 2019-08-11      33
# 2019-08-18      66
# 2019-08-25      49
# 2019-09-01      42
# 2019-09-08      42
# 2019-09-15      57
# 2019-09-22      61
# 2019-09-29      49
# 2019-10-06      48
# 2019-10-13      50
# 2019-10-20      54
# 2019-10-27      67
# 2019-11-03      50
# 2019-11-10      55
# 2019-11-17      63
# ...

# %%
data10.shape
# Out:
# (179, 1)

# %%
sns.boxplot(x="Profit", data=data10);

# %%
Q1=data10['Profit'].quantile(0.25)
Q3=data10['Profit'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)

Lower_Whisker= Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 60.0
# 274.0
# 214.0
# -261.0 595.0

# %%
data11 = data10[data10['Profit']< Upper_Whisker]

# %%
data11.shape
# Out:
# (170, 1)

# %%
data11.head()
# Out:
#             Profit
# Month
# 2019-01-06       2
# 2019-01-13       3
# 2019-01-20       6
# 2019-01-27       5
# 2019-02-03       1

# %%
# def sum_from_months_prior(row, data9):
#     '''returns sum of values in row month, 
#     from all dates in df prior to row date'''

#     month = pd.to_datetime(row).week

#     all_dates_prior = data9[data9.index <= row]
#     same_month = all_dates_prior[all_dates_prior.index.month == month]

#     return same_month["Profit"].sum()

# %%
# data9.set_index('month', inplace = True)
# data9.index = pd.to_datetime(data9.index)
# data9["month"] = data9.index
# data9.sort_index(inplace = True)

# data9["month"] = data9["month"].apply(lambda row: sum_from_months_prior (row, data9))
# data9.drop("month", axis = 1, inplace = True)

# %%
# data9

# %%
# data9.groupby(data9.index, sort=False).sum()

# %% [markdown]
# ##3.2 Time Series Plot

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plty

fig, ax = plty.subplots(figsize=(20,10))
plty.xlabel("Month")
plty.ylabel("Profit")

half_year_locator = mdates.MonthLocator(interval = 4)
year_month_formatter = mdates.DateFormatter('%Y-%m')

ax.xaxis.set_major_locator(half_year_locator)
ax.xaxis.set_major_formatter(year_month_formatter)

ax.plot(data11)
fig.autofmt_xdate()
plty.grid()
plty.show()

# %% [markdown]
# > **Insights:**
#
# * Dari grafik di atas, kita dapat melihat bahwa dari data Profit memiliki kombinasi yang terdiri dari beberapa pola yaitu tren yang menaik, pola seasonal, dan siklikal selama kurun waktu lebih dari 10 tahun (Jan 1949 s/d Dec 1960).
#
# * Lalu kita coba cek menggunakan seasonal plot untuk melihat lebih jelas melalui bantuan package seaborn dan membuat dataframe sementara (variabel: data2) untuk membuat visualisasi seasonal plot.

# %%
import pandas as pd                   # Alias digunakan untuk mempermudah kita memanggil software library dan methods didalamnya
import numpy as np                    # Numpy adalah paket dasar untuk komputasi ilmiah di python
from math import sqrt                 # memanggil function sqrt, operasi matematika akar
from pandas import Series             # function Series seperti aray 1 dimensi (dengan axis sebagai index) untuk menyimpan berbagai
                                      #tipe data, seperti integer, string, float, python objects, etc.

from matplotlib import pyplot         # pyplot adalah sekumpulan fungsi dari matplotlib yang membuatnya bekerja seperti halnya MATLAB.
from matplotlib.pyplot import figure  # figure memberikan identifier unik untuk sebuah gambar grafik dari pyplot
import matplotlib.pyplot as plt       # matplotlib adalah library komprehensif untuk membuat visualisasi statis, animasi, maupun interaktif di Python
figure(num=None, figsize=(16, 12), dpi=80, facecolor='w', edgecolor='k') # menetapkan format gambar grafik dg ukuran (16,12), dpi=80, facecolor=white, edgecolor=black
from matplotlib.pylab import rcParams # rc (runtime configuration) parameters, untuk merubah tampilan visual output matplotlib secara interaktif, 
                                      # (misal ubah warna, jenis garis untuk grafik dll)

import statsmodels.api as sm          # modul berisikan classes dan functions digunakan untuk estimasi model-model statistik, uji tes statistik, dan eksplorasi data.
import statsmodels.tsa.api as smt     # digunakan untuk mengakses Time-series models dan methods pd librari statsmodels
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt  # mengakses 3 modul holt-winters di modul time series analysis
from statsmodels.tsa.seasonal import seasonal_decompose #mengakses modul seasonal decompose pada modul time series analysis
from statsmodels.tsa.stattools import adfuller # mengakses function Augmented Dickey-Fuller unit root test. 
from statsmodels.tsa.arima_model import ARIMA  # mengakses function ARIMA
import statsmodels.formula.api as smf # digunakan untuk menentukan model dengan formula strings dan DataFrames.
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error 

from datetime import datetime         
import warnings                       # built-in modul untuk menghandle message dari issue warning, jika ada package yg obsolete
warnings.filterwarnings('ignore')     # filter untuk mengabaikan tipe warning
import sys                            # mengakses built-in function pada Python (args maupun keyword-args)
import itertools                      # digunakan iterasi pada struktur data yang dapat ditulis ulang menggunakan for-loop. 
                                      # Struktur data seperrti ini juga dikenal sebagai iterables
import seaborn as sns                 # Adalah library visualisasi data di Python yg berdasarkan matplotlib
# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# color_pal = ["#F8766D", "#D39200", "#93AA00",
#              "#00BA38", "#00C19F", "#00B9E3",
#              "#619CFF", "#DB72FB"]
# data10.plot(style='-', figsize=(20,5), color=color_pal[3], title="Profit")
# plt.show()

# %% [markdown]
# * Selanjutnya
#
#
# ---
#
#
# kita dapat cek secara visual (menggunakan rolling mean & std) dan melakukan uji statistik (statistical test) dengan Dickey-Fuller tes untuk melakukan konfirmasi apakah data yang dimiliki merepresentasikan bentuk stasioner.

# %% [markdown]
# ##3.3 Stationarity Check - Rolling Statistic test

# %%
# rolling dengan interval window sebesar 12 bulan dan hitung rata-rata
rolmean=data11.rolling(window=12).mean()  

# rolling dengan interval window sebesar 12 bulan dan hitung st. deviasi
rolstd=data11.rolling(window=12).std() 

# Tampilkan 15 baris pertama dari hasil rolling mean
print('15 baris pertama rolling mean: ')
print(rolmean.head(15))                
print ('')

# Tampilkan 15 baris pertama dari hasil rolling st. deviasi
print('15 baris pertama std. deviasi: ')
print(rolstd.head(15))
# Out:
# 15 baris pertama rolling mean:
#               Profit
# Month
# 2019-01-06       NaN
# 2019-01-13       NaN
# 2019-01-20       NaN
# 2019-01-27       NaN
# 2019-02-03       NaN
# 2019-02-10       NaN
# 2019-02-17       NaN
# 2019-02-24       NaN
# 2019-03-03       NaN
# 2019-03-10       NaN
# 2019-03-17       NaN
# 2019-03-24  6.916667
# 2019-03-31  7.333333
# 2019-04-07  8.166667
# 2019-04-14  9.916667
#
# 15 baris pertama std. deviasi:
#               Profit
# Month
# 2019-01-06       NaN
# 2019-01-13       NaN
# 2019-01-20       NaN
# 2019-01-27       NaN
# 2019-02-03       NaN
# 2019-02-10       NaN
# 2019-02-17       NaN
# 2019-02-24       NaN
# 2019-03-03       NaN
# 2019-03-10       NaN
# 2019-03-17       NaN
# 2019-03-24  4.122187
# 2019-03-31  3.821788
# 2019-04-07  3.880800
# 2019-04-14  6.598324

# %% [markdown]
# > Lalu, kita akan visualisasikan dari hasil rolling mean dan rolling std. deviasi untuk mengecek apakah apakah series ini stasioner atau tidak melalui bentuk visual grafik di bawah.

# %%
# atur ukuran chart
plt.figure(figsize=(20,10))

# buat multiple line chart berdasarkan warna dan label
actual=plt.plot(data11, color='red', label='Actual')
mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
std_6=plt.plot(rolstd, color='black', label='Rolling Std')

# tampilkan legend, judul dari chart, dan panggil function untuk menampilkan chart
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# > **Insights:**
#
# Dari grafik di atas kita dapat melihat bahwa data aktual dan rolling (mean dan std) memiliki bentuk yang cukup berbeda, menandakan bahwa **series** ini **tidak stasioner**.

# %% [markdown]
# ##3.4 Stationarity Check - Augmented Dickey-Fuller (ADF) test
#
# * Selanjutnya, kita akan gunakan ADF test untuk uji stasioner dimana:
#
#   **H0:** *The time series is non-stationary. In other words, it has some time-dependent structure and does not have constant variance over time.*
#
#  **H1:** *The time series is stationary.*
#
# * Jika p-value test kurang dari significance level (contoh alpha = 0.05) dan nilai ADF test lebih kecil dibandingkan critical values maka kita dapat reject null hypothesis dan dapat menyimpulkan bahwa time series adalah stasioner.

# %%
# menggunakan function adfuller() yang diterapkan pada variable Profit
print('Dickey-Fuller Test: ')
dftest=adfuller(data11['Profit'], autolag='AIC')
dftest
# Out:
# Dickey-Fuller Test:
# (4.991146109124978,
#  1.0,
#  7,
#  162,
#  {'1%': -3.471374345647024,
#   '10%': -2.5763733302850174,
#   '5%': -2.8795521079291966},
#  1371.455291731681)

# %%
# Supaya hasil uji lebih nyaman dibaca, maka kita buat series berdasarkan index 
dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])

# Gunakan for loop untuk menaruh value dari dictionary dengan function items()
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value

print('Dickey-Fuller Test: ')
print(dfoutput)
# Out:
# Dickey-Fuller Test:
# Test Statistic            4.991146
# p-value                   1.000000
# Lags Used                 7.000000
# No. of Obs              162.000000
# Critical Value (1%)      -3.471374
# Critical Value (5%)      -2.879552
# Critical Value (10%)     -2.576373
# dtype: float64

# %% [markdown]
# > **Insights:**
#
# Nilai ADF statistic yang jauh lebih besar dari critical values pada semua level, dan juga p-value yang lebih besar dari 0.05 turut menandakan, **kita gagal menolak null hypothesis pada 90%, 95%, dan 100% tingkat keyakinan**, yang **mengindikasikan** bahwa **data time series ini strongly non-stationary.**

# %% [markdown]
# * Berdasarkan insights di atas, maka kita akan mencoba menstabilkan variance dengan cara log transformation pada data AirPassenger dengan ``` np.log() ```

# %%
plt.figure(figsize=(20,10))
data_log=np.log(data11) #kita melakukan log analysis untuk men stabilkan variance dari sebuah series. 
plt.plot(data_log)

# %%
# Cek secara visual kembali dengan plot data_log dengan rolling window mean dan std. deviation
plt.figure(figsize=(20,10))

MAvg=data_log.rolling(window=12).mean() 
MStd=data_log.rolling(window=12).std()

plt.plot(data_log)
plt.plot(MAvg, color='blue')
#plt.plot(MStd, color='red')

# %%
# Hitung difference dari data_log dengan MAvg
data_log_diff=data_log-MAvg

# Tampilkan 12 baris teratas dari data_log_diff
data_log_diff.head(12)
# Out:
#               Profit
# Month
# 2019-01-06       NaN
# 2019-01-13       NaN
# 2019-01-20       NaN
# 2019-01-27       NaN
# 2019-02-03       NaN
# 2019-02-10       NaN
# 2019-02-17       NaN
# 2019-02-24       NaN
# 2019-03-03       NaN
# 2019-03-10       NaN
# 2019-03-17       NaN
# 2019-03-24  0.495487

# %%
# Efek dari rolling di atas, maka akan ada value NaN, sehingga kita bisa lakukan dropna()
data_log_diff=data_log_diff.dropna() 
data_log_diff.head()
# Out:
#               Profit
# Month
# 2019-03-24  0.495487
# 2019-03-31  0.139776
# 2019-04-07  0.636620
# 2019-04-14  1.242168
# 2019-04-21  1.101635

# %%
# Buat function stationarity untuk menampilkan multiple line chart dari actual, rolling mean, dan rolling std.deviasi
# yang juga berisikan hasil tes dari Dickey-Fuller

def stationarity(timeseries):
    
    rolmean=timeseries.rolling(window=12).mean()
    rolstd=timeseries.rolling(window=12).std()
    
    plt.figure(figsize=(20,10))
    actual=plt.plot(timeseries, color='red', label='Actual')
    mean_6=plt.plot(rolmean, color='green', label='Rolling Mean') 
    std_6=plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    print('Dickey-Fuller Test: ')
    dftest=adfuller(timeseries['Profit'], autolag='AIC')
    dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','No. of Obs'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
# panggil function dan terapkan pada data_log_diff
stationarity(data_log_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -3.774037
# p-value                   0.003184
# Lags Used                13.000000
# No. of Obs              145.000000
# Critical Value (1%)      -3.476273
# Critical Value (5%)      -2.881688
# Critical Value (10%)     -2.577513
# dtype: float64

# %% [markdown]
# > **Insights:**
#
# * Dapat dilihat dari hasil Dickey-Fuller test ini, bahwa untuk tingkat keyakinan 5% dan 10% sudah menunjukkan series ini stasioner dimana p-value 0.003184 yg < 0.05 menunjukkan bahwa kita menolak null hypothesis (reject to fail H0, accept H1), dan menyatakan bahwa series ini stasioner.
#
# * Kemudian, karena `t-value (-3.774037) < DF critical value 1% (-3.476273)` maka, kita bisa menerima null hypothesis (H0) yang menyatakan pada series ini tidak stasioner pd tingkat keyakinan 1% (*significance level* of 0.01).
#
# * Maka, kita dapat mencoba lagi dengan menggunakan Exponentially Weighted Moving Average (function `ewm`), karena melalui EWM kita dapat memberikan lebih banyak bobot kepada observasi terbaru, dengan kata lain dia akan memberikan bobot lebih sedikit terhadap data yang semakin jauh dari waktu kini, sehingga dia dapat menangkap tren terkini secara lebih cepat

# %%
# Visualisasikan ke dalam bentuk chart 
plt.figure(figsize=(20,10))

# Terapkan function ewm pada data_log melalui variable exp_data
exp_data=data_log.ewm(halflife=12, min_periods=0, adjust=True).mean() 

plt.plot(data_log)
plt.plot(exp_data, color='black')

# %%
# Hitung difference antara data_log dengan exp_data
exp_data_diff=data_log-exp_data

# Panggil function stationarity dan terapkan pada exp_data_diff
stationarity(exp_data_diff)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -1.830536
# p-value                   0.365410
# Lags Used                12.000000
# No. of Obs              157.000000
# Critical Value (1%)      -3.472703
# Critical Value (5%)      -2.880132
# Critical Value (10%)     -2.576683
# dtype: float64

# %% [markdown]
# > **Insights:**
#
# Sekarang, kita dapat melihat hasil melalui Dickey-Fuller test ini bahwa **nilai t-value (-1.830536) > DF critical value 1% (-3.472703)** maka kita dapat **reject null hypothesis**, dengan 90%, 95%, dan 99% tingkat keyakinan menyatakan bahwa series ini sudah stasioner.

# %% [markdown]
# ##3.5 Stationarity Check - Shift test

# %% [markdown]
# Shift test atau Differencing telah kita pelajari pada pertemuan ke 15 yang lalu, dimana kita akan menggeser satu waktu kebelakang (*backward shift*)

# %%
# Buat format ukuran chart
plt.figure(figsize=(20,10))

# Terapkan shift terhadap data yang telah diterapkan transformasi log di cell sebelumnya
data_shift=data_log-data_log.shift() 

# Tampilkan chart
plt.plot(data_shift)

# %%
# Check missing value
data_shift.isna().sum()
# Out:
# Profit    1
# dtype: int64

# %%
# Lakukan dropna 
data_shift=data_shift.dropna()

# Panggil function stationarity dan terapkan pada data_shift yang sudah dibersihkan dari NA value
stationarity(data_shift)
# Out:
# Dickey-Fuller Test:
# Test Statistic           -3.212930
# p-value                   0.019248
# Lags Used                11.000000
# No. of Obs              157.000000
# Critical Value (1%)      -3.472703
# Critical Value (5%)      -2.880132
# Critical Value (10%)     -2.576683
# dtype: float64

# %% [markdown]
# > **Insights:**
#
# * Dari `data_shift` di atas, hasil ADF test menunjukkan bahwa p-value < 0.05 sehingga kita ***(reject)*** gagal untuk menerima null hypothesis yang mengindikasikan bahwa series ini sudah stasioner.
#
# * Test statistic yang lebih besar dari Critical value pd 1% dan 5% juga menunjukkan hal demikian. Sehingga dalam observasi ini kita menyimpulkan bahwa series ini ***variant to time shift*** (mengalami perubahan pada pergeseran waktu)

# %% [markdown]
# ##3.6 Decomposition and Autocorrelation Function
#
# * Forecasting menggunakan data historikal dimana diurutkan dengan waktu, sehingga goal dari time series model yaitu untuk menemukan waktu dengan trend, seasonality, dan autocorrelation (correlation over time) lalu diformulasikan menjadi sebuah model.
#
# * Teknik Decomposition ini digunakan untuk split data time series menjadi beberapa komponen yaitu trend, seasonality, dan noise (residual) components.
#
# * Setiap komponen dapat digunakan untuk menunjukkan pola (pattern) yang ada di dalam tiap kategori agar dapat menentukan apakah model Additive atau Multiplicative.
#
#   * **Seasonality**: describes the periodic signal in your time series.
#   * **Trend**: describes whether the time series is decreasing, constant, or increasing over time.
#   * **Noise**: describes what remains behind the separation of seasonality and trend from the time series. In other words, it’s the variability in the data that cannot be explained by the model.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp=seasonal_decompose(data_log, freq=7)

trend=decomp.trend
seasonal=decomp.seasonal
residual=decomp.resid

plt.subplot(411)
plt.plot(data_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# > **Insights:**
#
# * Dari proses seasonal decompose, maka akan terbagi
# menjadi grafik original, trend (dalam hal ini dengan pola menaik), Seasonality (pola berulang yang terjadi dari tahun ke tahun), dan residuals (seberapa jauh titik data dari garis regresi).
#
# * Dapat dilihat bahwa trend dari time series Profit adalah semakin menaik, dan seasonality mengikuti pola.

# %%
# Tampilkan nilai dari tiap kategori dari 24 baris teratas
print("Trend \n",trend.head(24), '\n') # \n untuk menambahkan baris di akhir
print("Seasonal \n",seasonal.head(24), '\n')
print("Residual \n",residual.head(24), '\n')
# Out:
# Trend
#                Profit
# Month
# 2019-01-06       NaN
# 2019-01-13       NaN
# 2019-01-20       NaN
# 2019-01-27  1.195859
# 2019-02-03  1.451824
# 2019-02-10  1.637436
# 2019-02-17  1.736457
# 2019-02-24  1.861524
# 2019-03-03  2.175413
# 2019-03-10  2.255358
# 2019-03-17  2.365814
# 2019-03-24  2.481661
# 2019-03-31  2.609939
# 2019-04-07  2.667862
# 2019-04-14  2.824807
# 2019-04-21  2.986947
# 2019-04-28  3.208461
# 2019-05-05  3.301879
# 2019-05-12  3.346890
# 2019-05-19  3.272141
# 2019-05-26  3.279865
# 2019-06-02  3.248976
# 2019-06-09  3.214524
# 2019-06-16  3.242006
#
# Seasonal
#                Profit
# Month
# 2019-01-06  0.048412
# 2019-01-13 -0.017106
# 2019-01-20  0.020989
# 2019-01-27  0.056169
# 2019-02-03 -0.046348
# 2019-02-10 -0.035881
# 2019-02-17 -0.026235
# 2019-02-24  0.048412
# 2019-03-03 -0.017106
# 2019-03-10  0.020989
# 2019-03-17  0.056169
# 2019-03-24 -0.046348
# 2019-03-31 -0.035881
# 2019-04-07 -0.026235
# 2019-04-14  0.048412
# ...

# %% [markdown]
# > **Insights:**
#
# Dari data residual, kita dapat melihat banyak NA value, maka kita lakukan dropna

# %%
# assign variable baru decomp_data dengan variabel residual di atas
decomp_data=residual

# terapkan function dropna
decomp_data=decomp_data.dropna()

# Panggil function stationarity dan terapkan pada decomp data yang tanpa NA value
stationarity(decomp_data)
# Out:
# Dickey-Fuller Test:
# Test Statistic         -8.536186e+00
# p-value                 1.006540e-13
# Lags Used               1.000000e+01
# No. of Obs              1.530000e+02
# Critical Value (1%)    -3.473830e+00
# Critical Value (5%)    -2.880623e+00
# Critical Value (10%)   -2.576945e+00
# dtype: float64

# %% [markdown]
# > **Insights:**
#
# Dari komponen data residual, hasil ADF test menunjukkan bahwa bahwa nilai Test statistic yg jauh lebih kecil daripada critical value pd berbagai tingkat keyakinan. Dan p-value yang masih lebih besar dari 0.05, kita belum dapat menyatakan bahwa series ini cukup kuat stasioner.

# %% [markdown]
# **Autocorrelation Function (ACF) dan Partial Autocorrelation Function (PACF)**
#
# * Selanjutnya cara lain untuk melakukan tes stasioner adalah dengan menggunakan ACF dan PACF.
#
# * Masih ingat dengan konsep sederhana Correlation yang sudah kita dipelajari di topik Statistik sebelummnya? Kedua function berdasarkan konsep dari Correlation.
#
# * ACF merupakan korelasi antar data di dalam time series tersebut yang dipisahkan dalam lag dimana  (Xt , Xk+t) dengan k adalah jumlah lag dan t adalah nilainya.
#
# * Sama halnya dengan ACF, PACF juga menghitung korelasi antar data di time series. Perbedaannya, PACF juga menghitung korelasi antara Xt dan Xt+k namun sebelumnya menghilangkan data antara Xt dan Xt+k terlebih dahulu. Berarti data yang dihilangkan adalah data  Xt+1 sampai dengan Xt+k-1

# %%
# dari module time series analysis, import function acf dan pacf
# ACF = Auto Correlation Function
# PACF = Partial Auto Correlation Function
from statsmodels.tsa.stattools import acf, pacf 

# terapkan function acf dan pcf pada data_shift yang sudah dibuat
lag_acf=acf(data_shift, nlags=20)
lag_pacf=pacf(data_shift, nlags=20, method='ols')

# Format grafik dan visualisasikan ACF
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green') # y = -0.16
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green') # y = 0.16
plt.title('Autocorrelation Function / ACF')

# Format grafik dan visualisasikan PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='green')
plt.axhline(y=-1.96/np.sqrt(len(data_shift)),linestyle='--',color='green') # y = -0.16
plt.axhline(y=1.96/np.sqrt(len(data_shift)),linestyle='--',color='green') # y = 0.16
plt.title('Partial Autocorrelation Function / PACF')
# Out:
# Text(0.5, 1.0, 'Partial Autocorrelation Function / PACF')

# %% [markdown]
# > **Interpretation:**
#
# * Fungsi ACF dan PCF membantu kita dengan melakukan plot korelasi antara time series dan lag series tsb dengan 95% tingkat keyakinan ditandai dengan garis hijau putus-putus.
#
# * Jika nilai autocorrelation memotong/melewati garis putus-putus tersebut dapat diartikan bahwa specific lag tsb berkorelasi secara signifikan dengan time series yang ada.
#
# * Dari grafik di atas terlihat bahwa grafik time series (berwarna biru) berpotongan dengan grafik shift time series (dlm hal ini dengan lag=20) baik pada batas atas maupun bawah, sehingga dapat dikatakan bahwa grafik time series ini mengalami efek auto correlation.

# %% [markdown]
# # 4.Model Development
#
# > Pada Model Development, kita akan mencoba menerapkan 2 model time series yaitu:
# 1. fbProphet
# 2. Holt-Winters
# 3. SARIMAX

# %% [markdown]
# #### **4.1 Fbprophet**
#
# ****
#
# * Salah satu tools open source dari facebook

# %% [markdown]
# Pisahkan data menjadi train dan test data

# %%
# Membagi data kita menjadi data latih (data_train) dan data uji (data_test)
test_ratio = 0.2 #karena data kecil (ratusan)

test_set_size = int(len(data11) * test_ratio)
data_train = data11[0:-test_set_size].copy()
data_test = data11[-test_set_size:].copy()

# %%
# Melihat hasil pembagian data kita menggunakan visualisasi

data_test \
    .rename(columns={'Profit': 'TEST SET'}) \
    .join(data_train.rename(columns={'Profit': 'TRAINING SET'}),
          how='outer') \
    .plot(figsize=(15,5), title="Keuntungan Penjualan", style='-')
plt.show()

# %% [markdown]
# data oranye data latih, data biru data test

# %%
# Import Library yang akan digunakan untuk memprediksi Time-Series (FbProphet)

from fbprophet import Prophet

# %% [markdown]
# untuk memakai library tsb, data tanggal harus diganti menjadi **dy**, dan passenger menjadi **y**

# %%
# Preprocessing untuk menggunakan Prophet model ini untuk data_train

data_train.reset_index(inplace = True)
data_train.rename(columns={'Month':'ds', 'Profit':'y'}, inplace = True)
    
data_train
# Out:
#             ds    y
# 0   2019-01-06    2
# 1   2019-01-13    3
# 2   2019-01-20    6
# 3   2019-01-27    5
# 4   2019-02-03    1
# 5   2019-02-10    4
# 6   2019-02-17    6
# 7   2019-02-24   12
# 8   2019-03-03   11
# 9   2019-03-10   12
# 10  2019-03-17   12
# 11  2019-03-24    9
# 12  2019-03-31    7
# 13  2019-04-07   13
# 14  2019-04-14   27
# 15  2019-04-21   27
# 16  2019-04-28   18
# 17  2019-05-05   36
# 18  2019-05-12   28
# 19  2019-05-19   33
# 20  2019-05-26   25
# 21  2019-06-02   37
# 22  2019-06-09   16
# 23  2019-06-16   19
# 24  2019-06-23   29
# 25  2019-06-30   22
# 26  2019-07-07   40
# 27  2019-07-14   36
# 28  2019-07-21   50
# 29  2019-07-28   35
# 30  2019-08-04   47
# 31  2019-08-11   33
# 32  2019-08-18   66
# 33  2019-08-25   49
# 34  2019-09-01   42
# 35  2019-09-08   42
# 36  2019-09-15   57
# 37  2019-09-22   61
# 38  2019-09-29   49
# 39  2019-10-06   48
# 40  2019-10-13   50
# 41  2019-10-20   54
# 42  2019-10-27   67
# 43  2019-11-03   50
# ...

# %%
# Preprocessing untuk menggunakan Prophet model ini untuk data_test

data_test.reset_index(inplace = True)
data_test.rename(columns={'Month':'ds', 'Profit':'y'}, inplace = True)
    
data_test
# Out:
#            ds    y
# 0  2021-08-15  291
# 1  2021-08-22  324
# 2  2021-08-29  289
# 3  2021-09-05  267
# 4  2021-09-12  282
# 5  2021-09-19  284
# 6  2021-09-26  295
# 7  2021-10-03  350
# 8  2021-10-10  354
# 9  2021-10-17  312
# 10 2021-10-24  360
# 11 2021-10-31  334
# 12 2021-11-07  353
# 13 2021-11-14  363
# 14 2021-11-21  397
# 15 2021-11-28  382
# 16 2021-12-05  369
# 17 2021-12-12  413
# 18 2021-12-19  467
# 19 2021-12-26  389
# 20 2022-01-02  465
# 21 2022-01-09  493
# 22 2022-01-16  421
# 23 2022-01-23  455
# 24 2022-01-30  474
# 25 2022-02-06  484
# 26 2022-02-13  451
# 27 2022-02-20  463
# 28 2022-02-27  488
# 29 2022-03-06  529
# 30 2022-03-13  519
# 31 2022-03-20  555
# 32 2022-03-27  547
# 33 2022-06-05  569

# %%
#Untuk menguji Machine learning'
model1=Prophet()
model1.fit(data_train)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#ingin memprediksi menggunakan model ML kita
#data test fascet

data_test_fcst=model1.predict(data_test)

# %%
# Visualisai hasil prediksi machine learning

f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
fig = model1.plot(data_test_fcst,
                 ax=ax)
plt.show()

# %% [markdown]
# **hasil prediksi yang warna biru**

# %%
# Visualisasi perbandingan antara hasil prediksi machine learning dengan data yang asli
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.plot(data_test['ds'], data_test['y'], color='r')
fig = model1.plot(data_test_fcst, ax=ax)

# %% [markdown]
# Untuk prediksi waktu di masa depan
#
# buat variabel berupa dataframe baru

# %%
# Kita perlu ngebuat dataframe baru
prediksi_tahun_berikutnya = pd.DataFrame(columns=['ds', 'y'])
prediksi_tahun_berikutnya
# Out:
# Empty DataFrame
# Columns: [ds, y]
# Index: []

# %%
# Masukan tanggal dari tahun 1962 - 2028 ke kolom ds
prediksi_tahun_berikutnya['ds'] = pd.date_range(start='2023-01-01', end='2025-01-01')
prediksi_tahun_berikutnya
# Out:
#             ds    y
# 0   2023-01-01  NaN
# 1   2023-01-02  NaN
# 2   2023-01-03  NaN
# 3   2023-01-04  NaN
# 4   2023-01-05  NaN
# ..         ...  ...
# 727 2024-12-28  NaN
# 728 2024-12-29  NaN
# 729 2024-12-30  NaN
# 730 2024-12-31  NaN
# 731 2025-01-01  NaN
#
# [732 rows x 2 columns]

# %%
# Ingin memprediksi menggunakan model machine learning kita

data_test_baru_fcst = model1.predict(prediksi_tahun_berikutnya)

# %%
# Visualisai hasil prediksi machine learning

f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
fig = model1.plot(data_test_baru_fcst,
                 ax=ax)
plt.show()

# %%
# # Creating a train dataset
# train_prophet = data8.copy()
# train_prophet.reset_index(level=0, inplace=True)
# # Converting col names to specific names as required by Prophet library
# train_prophet = train_prophet.rename(columns = {'delivered_at': 'ds',
#                                 'Profit': 'y'})
# # Downsampling to week because modelling on daily basis takes a lot of time
# ts_week_prophet = train_prophet.set_index("ds").resample("W").sum()
# ts_week_prophet.head()

# %% [markdown]
# >>Fitting the Prophet model

# %%
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %%
# prophet_1 = Prophet()
# prophet_1.fit(train_prophet)

# future_1 = prophet_1.make_future_dataframe(periods = 52, freq = "W") 
# forecast_1 = prophet_1.predict(future)

# forecast_1[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()

# %%
# import concurrent.futures

# %%
# # Fitting data to Prophet model
# prophet_1 = Prophet() 
# prophet_1.fit(train_prophet)

# future_1 = prophet_1.make_future_dataframe(periods = 52, freq = "W") 
# forecast_1 = prophet_1.predict(futures)

# forecast_1[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail()

# %% [markdown]
# Pisahkan data menjadi train dan test data

# %%
# Split the data 
train = data11[0:int(len(data11)*0.80)]   #train data sebesar 80%
test = data11[int(len(data11)*0.80):]     #test data sebesar 20%

# %%
train.shape, test.shape
# Out:
# ((136, 1), (34, 1))

# %% [markdown]
# #### **4.2 HoltWinters**
#
# ****
#
# * Metode Holt-Winters adalah model dari time series behavior. Forecasting selalu memerlukan model, dan Holt-Winters adalah salah satu cara untuk modeling 3 aspek dari time series, yaitu : nilai rata-rata, slope dan seasonality

# %%
model_data = ExponentialSmoothing(np.asarray(train['Profit']),seasonal_periods=24, trend='add',seasonal='mul').fit(optimized=True)

# %%
#copy 29 bulan periode  untuk test dan assign ke data_Holt
data_Holt = test.copy()

# %%
data_Holt['Holt'] = model_data.forecast(len(test['Profit']))

# %%
data_Holt.tail()
# Out:
#             Profit        Holt
# Month
# 2022-03-06     529  380.032894
# 2022-03-13     519  360.024361
# 2022-03-20     555  372.716607
# 2022-03-27     547  392.239117
# 2022-06-05     569  345.915022

# %%
# mengubah data pada variable model_data menjadi dictionary
model_data.params
# Out:
# {'damping_slope': nan,
#  'initial_level': 102.66666666666667,
#  'initial_seasons': array([0.01948052, 0.02922078, 0.05844156, 0.0487013 , 0.00974026,
#         0.03896104, 0.05844156, 0.11688312, 0.10714286, 0.11688312,
#         0.11688312, 0.08766234, 0.06818182, 0.12662338, 0.26298701,
#         0.26298701, 0.17532468, 0.35064935, 0.27272727, 0.32142857,
#         0.24350649, 0.36038961, 0.15584416, 0.18506494]),
#  'initial_slope': 1.3645833333333333,
#  'lamda': None,
#  'remove_bias': False,
#  'smoothing_level': 0.05263157894736842,
#  'smoothing_seasonal': 0.7894736842105263,
#  'smoothing_slope': 0.05263157894736842,
#  'use_boxcox': False}

# %%
# Visualisasi hasil forecast dari model Holt Winters dengan data aktual
plt.figure(figsize=(16,8))
plt.plot(train['Profit'], label='Train')
plt.plot(test['Profit'], label='Test')
plt.plot(data_Holt['Holt'], label='Holt Trend Add Seasonal Mul')
plt.legend(loc=0)

# %% [markdown]
# > **Keterangan:**
#
# * Dari grafik di atas terlihat bahwa model Holt-winters mulai melakukan prediksi pd 1958-08 s/d 1960-12 yang ditunjukkan oleh garis berwarna hijau.
#
# * Garis berwarna biru merupakan data yang digunakan untuk train dan garis berwarna oranye yang digunakan untuk test.

# %% [markdown]
# #### **4.3 SARIMAX**
#
# ****
#
# * **SARIMAX** (Seasonal Auto-Regressive Integrated Moving Average with eXogenous factors) adalah versi update dari model ARIMA, dapat dikatakan bahwa SARIMAX model seasonal equivalent seperti halnya SARIMA dan Auto ARIMA, yang mana model ini dapat juga memperhitungkan efek eksternal.
#
# * Karena ARIMA tidak mendukung seasonality, maka beda dengan SARIMAX yang dapat digunakan pada data set yang memiliki siklus musiman (*seasonality*).
#
# * terdiri dari 3 parameter yaitu (p, d, dan q)
#   * p is the order of the AR term
#   * q is the order of the MA term
#   * d is the number of differencing required to make the time series stationary

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, d and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
temp_model = None
train_log = np.log10(train['Profit'])

# %%
for param in pdq: #Non-Seasonal
    for param_seasonal in seasonal_pdq:
        
        try:
            temp_model = sm.tsa.statespace.SARIMAX(train_log,
                                             order = param,
                                             seasonal_order = param_seasonal)
            results = temp_model.fit()

            # print("SARIMAX{}x{}12 - AIC:{}".format(param, param_seasonal, results.aic))
            if results.aic < best_aic:
                best_aic = results.aic
                best_pdq = param
                best_seasonal_pdq = param_seasonal #Store the best param values : AIC, P, D, Q [Non-S / Seas]
        except:
            #print("Unexpected error:", sys.exc_info()[0])
            continue
print("Best SARIMAX{}x{}12 model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
# Out:
# Best SARIMAX(0, 1, 1)x(0, 0, 1, 12)12 model - AIC:-187.67376263629598

# %%
# tampilkan hasil dari SARIMAX
mod = sm.tsa.statespace.SARIMAX(train_log,
                                order=(0,1,1),
                                seasonal_order=(0,0,1,12),
                                enforce_stationary=True)

best_results = mod.fit()

print(best_results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4640      0.050     -9.328      0.000      -0.561      -0.367
# ma.S.L12       0.3790      0.088      4.304      0.000       0.206       0.552
# sigma2         0.0137      0.001     12.473      0.000       0.012       0.016
# ...

# %%
# Terapkan function get_prediction() pada best_results
pred_dynamic = best_results.get_prediction(start=pd.to_datetime('2022-06-05'), dynamic=True, full_results=True)
pred_dynamic

# %%
pred_dynamic_ci = pred_dynamic.conf_int()
pred_dynamic_ci
# Out:
#             lower Profit  upper Profit
# 2022-06-05       1.37634       3.50063

# %%
pred99 = best_results.get_forecast(steps=29, alpha=0.1)
pred99

# %%
# ekstrak predicted and true values of our time series
# sales_ts_forecasted = pred_dynamic.predicted_mean

testCopy = test.copy()
testCopy['Profit_Forecast'] = np.power(10, pred99.predicted_mean)

# %%
testCopy.tail(10)
# Out:
#             Profit  Profit_Forecast
# Month
# 2022-01-30     474       274.463784
# 2022-02-06     484       274.463784
# 2022-02-13     451       274.463784
# 2022-02-20     463       274.463784
# 2022-02-27     488       274.463784
# 2022-03-06     529              NaN
# 2022-03-13     519              NaN
# 2022-03-20     555              NaN
# 2022-03-27     547              NaN
# 2022-06-05     569              NaN

# %%
axis = train['Profit'].plot(label='Train Profit', figsize=(10, 6))
testCopy['Profit'].plot(ax=axis, label='Test Profit', alpha=0.7)
testCopy['Profit_Forecast'].plot(ax=axis, label='Forecasted ', alpha=0.7)
axis.set_xlabel('Month')
axis.set_ylabel('Profit')
plt.legend(loc='best')
plt.show()
plt.close()

# %% [markdown]
# # 5.Plot Forecast with Interval Keyakinan (Confidence Band)
#
# > Tahap ini kita akan melakukan visualisasi nilai prediksi beserta interval keyakinan

# %% [markdown]
# Forecast #Passengers using the best fit model

# %%
# get forecast 36 steps (3 tahun) ahead in the future
n_steps = 36
pred_uc_99 = best_results.get_forecast(steps = 36, alpha = 0.01) # alpha = 0.01 signifies 99% Confidence interval
pred_uc_95 = best_results.get_forecast(steps=36, alpha = 0.05) # alpha = 0.05 95% CI

# get confidence level intervals 95% & 99% of the forecasts
pred_ci_99 = pred_uc_99.conf_int()
pred_ci_95 = pred_uc_95.conf_int()

# %%
n_steps = 36
idx = pd.date_range(data11.index[-1], periods=n_steps, freq='MS')
fc_95 = pd.DataFrame(np.column_stack([np.power(10, pred_uc_95.predicted_mean), np.power(10, pred_ci_95)]), 
                     index=idx, columns=['forecast', 'lower_ci_95', 'upper_ci_95'])
fc_99 = pd.DataFrame(np.column_stack([np.power(10, pred_ci_99)]), 
                     index=idx, columns=['lower_ci_99', 'upper_ci_99'])
fc_all = fc_95.combine_first(fc_99)
fc_all = fc_all[['forecast', 'lower_ci_95', 'upper_ci_95', 'lower_ci_99', 'upper_ci_99']] # just reordering columns
fc_all.head()
# Out:
#               forecast  lower_ci_95  upper_ci_95  lower_ci_99  upper_ci_99
# 2022-07-01  270.155253   159.203167   458.432215   159.203167   458.432215
# 2022-08-01  278.001726   152.571791   506.548161   152.571791   506.548161
# 2022-09-01  257.488179   132.607863   499.971577   132.607863   499.971577
# 2022-10-01  276.346888   134.299938   568.634683   134.299938   568.634683
# 2022-11-01  266.239018   122.625753   578.045095   122.625753   578.045095

# %%
# plot the forecast along with the confidence band
axis = data11['Profit'].plot(label='Observed', figsize=(8, 4))
fc_all['forecast'].plot(ax=axis, label='Forecast', alpha=0.7)
axis.fill_between(fc_all.index, fc_all['lower_ci_95'], fc_all['upper_ci_95'], color='k', alpha=.15)
axis.set_xlabel('Years')
axis.set_ylabel('Profit')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # 6.Model Evaluation
#
# >Sekarang kita akan melakukan validasi dan evaluasi terhadap model yang telah kita buat

# %% [markdown]
# **Plot ACF and PACF for residuals of SARIMAX model**

# %%
best_results.plot_diagnostics(lags=30, figsize=(16,12))
plt.show()

# %% [markdown]
# * Grafik standardized residuals menunjukkan bahwa sebagian besar titik sudah berada pada y=0 yang berarti bahwa prediksi tidak menyimpang jauh dari data aktual.
#
# * Grafik histogram sudah menunjukkan kecenderungan normal (garis hijau adalah grafik garis dari ujung histogram) dan KDE menunjukkan grafik kecocokan prediksi.
#
# * Q–Q plot adalah probability plot, yang mana digunakan untuk mengecek apakah data kita berada pada garis normal.
#
# * Correlogram, juga dikenal sebagai Auto Correlation Function (ACF) plot, meruapakan cara grafis untuk memperlihatkan korelasi serial pada data yang tidak selalu konstan dalam kurun waktu tertentu. Correlogram akan memperlihatkan gambaran apakah terdapat auto-correlation diantara pasangan data pada kurun waktu yang berbeda.

# %%
from statsmodels.tsa.arima_model import ARIMA #dari library statsmodel time series analysis kita akan melakukan import module Autoregressive integrated moving average

plt.figure(figsize=(20,10))
model=ARIMA(data_log, order=(2,1,2))
results=model.fit(disp=-1)
plt.plot(data_shift)
plt.plot(results.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results.fittedvalues-data_shift['#Passengers'])**2))
print('plotting ARIMA model')

# %% [markdown]
# # 7.Model Validation
#
# >Sekarang kita akan melakukan validasi terhadap model yang telah kita buat

# %%
predictions=pd.Series(results.fittedvalues, copy=True)
print(predictions.head())

# %%
predictions_cum_sum=predictions.cumsum() #melakukan perhitungan cumulative sum
print(predictions_cum_sum.head())

# %%
predictions_log=pd.Series(data_log['#Passengers'], index=data_log.index)
predictions_log=predictions_log.add(predictions_cum_sum,fill_value=0)
predictions_log.head()

# %%
predictions_ARIMA=np.exp(predictions_log)
plt.figure(figsize=(20,10))
plt.plot(data)
plt.plot(predictions_ARIMA)

# %% [markdown]
# > Model performance based on MAE, MSE, RMSE, MAPE

# %% [markdown]
# * Model HoltWinters

# %%
# Hitung MAE pada model HoltWinters menggunakan function yang dibuat dari awal
def mean_absolute_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs(y_true - y_pred)) 

# Hitung MAPE pada model HoltWinters
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Hitung MSE dan RMSE pada model HoltWinters
mse = ((test['Profit'] - data_Holt['Holt']) ** 2).mean()
rmse = np.sqrt(mse)

print('Mean Absolute Error of our forecasts is ', mean_absolute_error(test['Profit'],data_Holt['Holt']).round(3))
print('Mean Absolute Percentage Error of our forecasts is ', mean_absolute_percentage_error(test['Profit'],data_Holt['Holt']).round(2), ' %')
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 3)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 3)))
# Out:
# Mean Absolute Error of our forecasts is  86.071
# Mean Absolute Percentage Error of our forecasts is  19.38  %
# The Mean Squared Error of our forecasts is 10966.376
# The Root Mean Squared Error of our forecasts is 104.72

# %% [markdown]
# * Model SARIMAX

# %%
# Import module metrics dan panggil functionnya
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

y_true = test['Profit']
y_pred = testCopy['Profit']

print('The Mean Absolute Error of our forecasts is ', mean_absolute_error(y_true, y_pred).round(3))
print ('The Mean Absolute Percentage Error of our forecasts is ', mean_absolute_percentage_error(y_true, y_pred).round(3), '%')
print ('The Mean Squared Error of our forecasts is ', mean_squared_error(y_true, y_pred).round(3))
print ('The Root Mean Squared Error of our forecasts is ', np.sqrt(mean_squared_error(y_true, y_pred)).round(3))
# Out:
# The Mean Absolute Error of our forecasts is  0.0
# The Mean Absolute Percentage Error of our forecasts is  0.0 %
# The Mean Squared Error of our forecasts is  0.0
# The Root Mean Squared Error of our forecasts is  0.0

# %% [markdown]
# ### 7.1 Pengujian ML

# %% [markdown]
# 1. Holtwinter

# %%
# Pengujian Machine Learning Kita

data_hasil_prediksi_pertama = test.copy() 
data_hasil_prediksi_pertama['hasil_prediksi'] = model_data.forecast(len(test['Profit'])).astype(int)

# %% [markdown]
# ### 7.2 Hasil Prediksi

# %%
# Menampilkan hasil prediksi kita
data_hasil_prediksi_pertama
# Out:
#             Profit  hasil_prediksi
# Month
# 2021-08-15     291             252
# 2021-08-22     324             237
# 2021-08-29     289             311
# 2021-09-05     267             304
# 2021-09-12     282             283
# 2021-09-19     284             306
# 2021-09-26     295             290
# 2021-10-03     350             301
# 2021-10-10     354             318
# 2021-10-17     312             281
# 2021-10-24     360             322
# 2021-10-31     334             372
# 2021-11-07     353             308
# 2021-11-14     363             315
# 2021-11-21     397             295
# 2021-11-28     382             339
# 2021-12-05     369             307
# 2021-12-12     413             315
# 2021-12-19     467             316
# 2021-12-26     389             326
# 2022-01-02     465             314
# 2022-01-09     493             335
# 2022-01-16     421             380
# 2022-01-23     455             384
# 2022-01-30     474             315
# ...

# %%
# Pengujian Machine Learning Kita

hasil_prediksi_kedua = best_results.get_forecast(steps=len(test)+1, alpha=0.1)
data_hasil_prediksi_kedua = test.copy()
data_hasil_prediksi_kedua['hasil_prediksi'] = np.power(10, hasil_prediksi_kedua.predicted_mean).astype(int)

# %%
data_hasil_prediksi_kedua
# Out:
#             Profit  hasil_prediksi
# Month
# 2021-08-15     291           270.0
# 2021-08-22     324           278.0
# 2021-08-29     289           257.0
# 2021-09-05     267           276.0
# 2021-09-12     282           266.0
# 2021-09-19     284           266.0
# 2021-09-26     295           269.0
# 2021-10-03     350           270.0
# 2021-10-10     354           264.0
# 2021-10-17     312           278.0
# 2021-10-24     360           288.0
# 2021-10-31     334           268.0
# 2021-11-07     353           274.0
# 2021-11-14     363           274.0
# 2021-11-21     397           274.0
# 2021-11-28     382           274.0
# 2021-12-05     369           274.0
# 2021-12-12     413           274.0
# 2021-12-19     467           274.0
# 2021-12-26     389           274.0
# 2022-01-02     465           274.0
# 2022-01-09     493           274.0
# 2022-01-16     421           274.0
# 2022-01-23     455           274.0
# 2022-01-30     474           274.0
# ...

# %% [markdown]
# ## 7.3 Hasil perbedaan Holtwinter dan Sarimax

# %%
np.any(np.isnan(data_hasil_prediksi_kedua))
# Out:
# True

# %%
data_hasil_prediksi_kedua=data_hasil_prediksi_kedua.dropna()

# %%
np.all(np.isfinite(data_hasil_prediksi_kedua))
# Out:
# True

# %%
# Hasil Score dari kedua model HotWinter dan Sarimax

print('Hasil Score model HotWinter', mean_absolute_error(
    data_hasil_prediksi_pertama['Profit'], data_hasil_prediksi_pertama['hasil_prediksi']))

print('Hasil Score model Sarimax', mean_absolute_error(
    data_hasil_prediksi_kedua['Profit'], data_hasil_prediksi_kedua['hasil_prediksi']))
# Out:
# Hasil Score model HotWinter 86.41176470588235
# Hasil Score model Sarimax 128.27272727272728

# %%
# Hasil Score MAPE dari kedua model HoltWinter dan Sarimax

print('Hasil Score MAPE model HoltWinter', mean_absolute_percentage_error(
    data_hasil_prediksi_pertama['Profit'], data_hasil_prediksi_pertama['hasil_prediksi']))

print('Hasil Score MAPE model Sarimax', mean_absolute_percentage_error(
    data_hasil_prediksi_kedua['Profit'], data_hasil_prediksi_kedua['hasil_prediksi']))
# Hasil Score MSE dari kedua model HoltWinter dan Sarimax

print('Hasil Score MSE model HoltWinter', mean_squared_error(
    data_hasil_prediksi_pertama['Profit'], data_hasil_prediksi_pertama['hasil_prediksi']))

print('Hasil Score MSE model Sarimax', mean_squared_error(
    data_hasil_prediksi_kedua['Profit'], data_hasil_prediksi_kedua['hasil_prediksi']))
# Out:
# Hasil Score MAPE model HoltWinter 0.19448538358864684
# Hasil Score MAPE model Sarimax 0.2902155812997309
# Hasil Score MSE model HoltWinter 11047.176470588236
# Hasil Score MSE model Sarimax 23157.18181818182

# %% [markdown]
# # 8.Referensi

# %% [markdown]
# * [ARIMA](https://daps.bps.go.id/file_artikel/77/arima.pdf)
# * [Time Series - Interpreting ACF and PACF](https://www.kaggle.com/code/iamleonie/time-series-interpreting-acf-and-pacf/notebook)
# * [How to decompose time series data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/#:~:text=The%20seasonal_decompose()%20function%20returns,components%20assuming%20an%20additive%20model.)
# * [SARIMAX - Introduction](https://www.statsmodels.org/dev/examples/notebooks/generated/statespace_sarimax_stata.html)
# * [Complete Guide To SARIMAX in Python for Time Series Modeling](https://analyticsindiamag.com/complete-guide-to-sarimax-in-python-for-time-series-modeling/)
# * [Holt-Winters’ seasonal method](https://otexts.com/fpp2/holt-winters.html)
# * [Time Series Analysis: Resampling, Shifting and Rolling](https://towardsdatascience.com/time-series-analysis-resampling-shifting-and-rolling-f5664ddef77e)
# * [EDA](https://medium.com/@izza.aditya.12.ia/exploratory-data-analysis-c0b6bf5ae706)
# * [fbProphet](https://medium.com/analytics-vidhya/predicting-sales-time-series-analysis-forecasting-with-python-b81d3e8ff03f)
